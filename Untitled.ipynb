# %%
from __future__ import division
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.preprocessing import scale

from code.organize import *
from code.roughEDA import *
from code.survey_processor_full import *
from code.model_vis import *
from code.fc import *
from code.fc_cluster import *
from code.clusterEDA import *


import plotly.plotly as py
from plotly.tools import FigureFactory as FF
import plotly.graph_objs as go

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# In this file, I will wrapp up the clusions from step7_cluster_study and more concise graphs.

# %%
df = pd.read_pickle('data/df_id.pkl')       # Load survey data with cluster_id
fc = FeatureContribution('data/fc_df2.pkl')  # Load feature contribution data
fc_df = fc.cluster_processor(3,6)            # generate cluster

# %% [markdown]
# # Cluster 1
#
# Main contributors
# * agekdbrn: historgram and median. Median is easier to interpret and I will use to for presentation slide.

# %%
c1 =df[df.cluster==1]

# %%
plt.figure(figsize=(7,5))
one_res_hist_mat(df,1,'agekdbrn')

# %%
c1.agekdbrn.median()
# Out:
# 19.0

# %% [markdown]
# * degree: Respondents' degree in this cluster is very speciall. All less than high school. So I can just write a sentence or use an icon to summerize it.

# %% [markdown]
# * dwelling, class_ and incom16

# %%
dwel = one_res_bar(df,1,'dwelling')

# %%
dwel_n = dwel.apply(lambda x: x/x.sum(), axis =1)

# %%
dwel_n_sub = dwel_n[['Row house','Trailer']]

# %%
cla = one_res_bar(df,1,'class_')

# %%
cla_n= cla.apply(lambda x: x/x.sum(), axis =1)

# %%
cla_n_sub = cla_n['Lower class']

# %%
in16 = one_res_bar(df,1,'incom16')

# %%
in16_n = in16.apply(lambda x: x/x.sum(), axis =1)

# %%
in16_n_sub= in16_n[['Far below average','Below average']]

# %%
all = pd.concat([dwel_n_sub,cla_n_sub,in16_n_sub], axis=1)

# %%
all
# Out:
#            Row house   Trailer  Lower class  Far below average  Below average
# Rest        0.060429  0.065546     0.073140           0.091152       0.235216
# Cluster_1   0.117808  0.117808     0.236467           0.161458       0.343750

# %%
trace0 = go.Bar(
    x=['Row house','Trailer'],
    y=[0.060429,0.065546],
    name='dwelling rest',
    marker=dict(
        color='rgb(49,130,189)'
    )
)

trace1 = go.Bar(
    x = ['Row house','Trailer'],
    y = all.iloc[1,:2].values,
    name = 'dwelling cluster 1',
    marker=dict(
        color='rgb(136, 198, 12)'
    )
)
trace2 = go.Bar(
    x = ['Lower class'],
    y = all.iloc[0,2],
    name = 'class rest',
    marker = dict(
        color = 'rgb(10, 97, 142)'
    )
)
trace3 = go.Bar(
    x = ['Lower clas'],
    y = all.iloc[1,2],
    name = 'class cluster1',
    marker = dict(
        color = 'rgb(245, 111, 136)'
    )
)
data = [trace0, trace1,trace2,trace3]
fig = go.Figure(data=data)
py.iplot(fig, filename = "cluster1")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~yihua/102.embed" height="525px" width="100%"></iframe>

# %%
all
# Out:
#            Row house   Trailer  Lower class  Far below average  Below average
# Rest        0.060429  0.065546     0.073140           0.091152       0.235216
# Cluster_1   0.117808  0.117808     0.236467           0.161458       0.343750

# %%
trace0 = go.Bar(
    x = all.columns,
    y = all.iloc[0,:].values,
    name = 'rest',
    marker = dict(
        color = ['rgb(10, 97, 142)', 'rgb(10, 97, 142)', 'rgb(6, 80, 177)','rgb(7, 87, 197)','rgb(7, 87, 197)']
    )
)
trace1 = go.Bar(
    x = all.columns,
    y = all.iloc[1,:].values,
    name = 'cluster1',
    marker = dict(
        color = ['rgb(245, 111, 136)','rgb(245, 111, 136)','rgb(248, 32, 113)','rgb(248, 80, 58)', 'rgb(248, 80, 58)']
    )
)
data = [trace0,trace1]
    
    
fig = go.Figure(data=data)
py.iplot(fig, filename = "cluster1")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~yihua/102.embed" height="525px" width="100%"></iframe>

# %%
for i in all.values:
    print i
# Out:
# [ 0.06042885  0.06554581  0.07313965  0.09115162  0.23521565]
# [ 0.11780822  0.11780822  0.23646724  0.16145833  0.34375   ]
