# %%
from __future__ import division
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns

from code.organize import *
from code.roughEDA import *
from code.survey_processor_full import *
from code.model_vis import *
from code.fc import *
from code.fc_cluster import *
from code.clusterEDA import *

import plotly.plotly as py
from plotly.tools import FigureFactory as FF
import plotly.graph_objs as go

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # FC Cluster Study
#
# In this file, I will analysis data in each cluster.

# %%
df = pd.read_pickle('data/df_id.pkl')       # Load survey data with cluster_id

# %%
fc = FeatureContribution('data/fc_df2.pkl')  # Load feature contribution data
fc_df = fc.cluster_processor(3,6)            # generate cluster

# %% [markdown]
# ### Cluster 1

# %% [markdown]
# #### Details in their answers

# %%
one_res_all(df,1)

# %%
c1 = fc_df[fc_df.cluster == 1]

# %% [markdown]
# These features are the top 10 features driving the decision.

# %%
sort_feature_means(c1,10)
# Out:
# [(-0.12551662685679615, 'degree'),
#  (-0.063086126768045356, 'coninc'),
#  (-0.021723891743851996, 'age'),
#  (-0.017084660320522339, 'agekdbrn'),
#  (-0.016895788647500305, 'educom'),
#  (-0.014650047797046557, 'class_'),
#  (-0.011659304310631145, 'polviews'),
#  (-0.010897973232229251, 'incom16'),
#  (-0.010461340957816267, 'dwelling'),
#  (-0.0095513131604080034, 'socfrend')]

# %% [markdown]
# ### Degree: public vs cluster1

# %%
dgr1 = one_res_bar(df,1,'degree')

# %%
cluster_ztest_df(dgr1)
# Out:
# [(u'Lt high school', 49.4, 0.0)]

# %% [markdown]
# ## class

# %%
class1 = one_res_bar(df,1,'class_',(10,5))

# %%
cluster_ztest_df(class1)
# Out:
# [(u'Lower class', 10.43, 0.0), (u'Middle class', -4.25, 0.0)]

# %% [markdown]
# ## political views

# %%
pvw1 = one_res_bar(df,1,'polviews',(10,5))

# %%
cluster_ztest_df(pvw1)
# Out:
# [(u"Don't know", 7.46, 0.0), (u'Extremely liberal', 4.99, 0.0)]

# %% [markdown]
# ### income 16

# %%
icm1 = one_res_bar(df,1,'incom16')

# %%
cluster_ztest_df(icm1)
# Out:
# [(u'Above average', -3.78, 0.0),
#  (u'Average', -3.44, 0.0),
#  (u'Below average', 3.36, 0.0),
#  (u'Far below average', 3.16, 0.0),
#  (u'No answer', 8.42, 0.0)]

# %% [markdown]
# ## dwelling

# %%
dw_1 = one_res_bar(df,1,'dwelling')

# %%
cluster_ztest_df(dw_1)
# Out:
# [(u'3-4 fam house', 4.02, 0.0),
#  (u'Detached 1-fam house', -9.17, 0.0),
#  (u'Row house', 4.26, 0.0),
#  (u'Trailer', 3.75, 0.0)]

# %% [markdown]
# ### socfrend

# %%
sfrd1=one_res_bar(df,1,'socfrend')

# %%
cluster_ztest_df(sfrd1)
# Out:
# [(u'Never', 9.46, 0.0)]

# %% [markdown]
# ## Women in cluster 1 have following characteristics:
#   * They don't have high degree. all of them have less than high school degree. **Main decision driver**
#   * Their median age of giving birth to their first child is 19, way lower than the entire population (23)
#   * They are generally younger the public.
#   * Their median family income is below population median and they consider their finanicial situations are below average. More of them consider themselve lower class than population.
#   * They grow up in poor families. More of them responded their family income when they're 16 are below or far below average.
#   * When asking their political views, the proportion of "don't know" is higher than the public. They probablity don't have strong interest in politics.
#   * most of them answer they never spend evening with friends.
#
#   ### Summary: They have children early, less educated, from less educated family and living in poor conditions.

# %% [markdown]
# ### Cluster 2

# %%
one_res_all(df,2)

# %%
c2 = fc_df[fc_df.cluster ==2]

# %% [markdown]
# Top 10 driving features

# %%
sort_feature_means(c2,10)
# Out:
# [(-0.034108965757154275, 'age'),
#  (-0.032352318019756555, 'educom'),
#  (-0.029752545104176506, 'sphrs1'),
#  (-0.02332004490984585, 'agekdbrn'),
#  (-0.018308817158882766, 'partyid'),
#  (-0.016054668892952786, 'divorce'),
#  (-0.015780474788718659, 'polviews'),
#  (-0.015230611110697389, 'res16'),
#  (-0.014822270722593071, 'incom16'),
#  (-0.013142176042391294, 'reliten')]

# %% [markdown]
# ## party id

# %%
pid2 = one_res_bar(df,2,'partyid')

# %%
cluster_ztest_df(pid2)
# Out:
# [(u'Independent', -4.13, 0.0),
#  (u'Not str republican', 3.76, 0.0),
#  (u'Strong republican', 5.87, 0.0)]

# %% [markdown]
# ### divorce

# %%
div2 = one_res_bar(df,2,'divorce')

# %%
cluster_ztest_df(div2)
# Out:
# [(u'No', 3.03, 0.0), (u'Yes', -3.21, 0.0)]

# %% [markdown]
# ## Political views

# %%
polv2 = one_res_bar(df,2,'polviews')

# %%
cluster_ztest_df(polv2)
# Out:
# [(u"Don't know", -3.87, 0.0), (u'Extrmly conservative', 3.87, 0.0)]

# %% [markdown]
# ### res16

# %%
res16_2 = one_res_bar(df,2,'res16')

# %%
cluster_ztest_df(res16_2,False)
# Out:
# [(u'Big-city suburb', 1.95, 0.03)]

# %% [markdown]
# ## religion

# %%
rg2 = one_res_bar(df,2,'reliten')

# %%
cluster_ztest_df(rg2)
# Out:
# [(u'Not very strong', -3.11, 0.0), (u'Strong', 4.37, 0.0)]

# %% [markdown]
# ### Women in cluster 2 have flowing characteristics:
#   * Their husbands work longer than population. Their median family incomes are higher than population.
#   * They have high shool or college degrees and their family members' education years are also longer than the public.
#   * They gave birth to their first babies are later than the public.
#   * Their most voted partyid are "not strong republican" and "republican", more conservative political views and strong affiliation to religions.
#   * majority of them never divorced.
#   * They grow up in a family whose income are above average.
#
#   ## summary: Women in this cluster grow up in rich family and currently living in a rich family. They are well educated and conservative.

# %% [markdown]
# ## Cluster 5

# %%
one_res_all(df,5)

# %%
c5 = fc_df[fc_df.cluster ==5]
sort_feature_means(c5,10)
# Out:
# [(-0.093809534881303766, 'coninc'),
#  (-0.0312724426093983, 'age'),
#  (-0.029551005469015224, 'class_'),
#  (0.019182486357316935, 'degree'),
#  (-0.018363747960816187, 'agekdbrn'),
#  (-0.017130624677715166, 'educom'),
#  (-0.016918200320531627, 'polviews'),
#  (-0.016657950553904989, 'finrela'),
#  (-0.015951338405862891, 'partyid'),
#  (-0.013361867723130388, 'dwelling')]

# %% [markdown]
# ## class

# %%
class_5 = one_res_bar(df,5,'class_')

# %%
cluster_ztest_df(class_5)
# Out:
# [(u'Lower class', 15.45, 0.0),
#  (u'Middle class', -5.79, 0.0),
#  (u'Upper class', 2.97, 0.0),
#  (u'Working class', -4.0, 0.0)]

# %% [markdown]
# ## degree

# %%
dgr5 = one_res_bar(df,5,'degree')

# %%
cluster_ztest_df(dgr5)
# Out:
# [(u'Bachelor', -4.28, 0.0),
#  (u'Graduate', -4.33, 0.0),
#  (u'High school', 12.41, 0.0),
#  (u'No answer', 3.41, 0.0)]

# %% [markdown]
# ## political views

# %%
plv5 = one_res_bar(df,5,'polviews')

# %%
cluster_ztest_df(plv5)
# Out:
# []

# %% [markdown]
# ### Finance

# %%
f5 = one_res_bar(df,5,'finrela')

# %%
cluster_ztest_df(f5)
# Out:
# [(u'Above average', -3.77, 0.0),
#  (u'Average', -7.94, 0.0),
#  (u'Below average', 4.55, 0.0),
#  (u'Far below average', 10.85, 0.0)]

# %% [markdown]
# ### Partyid

# %%
pid5 = one_res_bar(df,5,'partyid')

# %%
cluster_ztest_df(pid5,False)
# Out:
# [(u'Independent', 2.88, 0.0), (u'Not str republican', -2.71, 0.0)]

# %%
dw5 = one_res_bar(df,5,'dwelling')

# %%
cluster_ztest_df(dw5)
# Out:
# [(u'Apartment house', 5.02, 0.0),
#  (u'Apartment-4 stories', 4.77, 0.0),
#  (u'Detached 1-fam house', -6.45, 0.0)]

# %% [markdown]
# ### Women in cluster 5 have flowing characteristics:
#   * They are from poor family. Their median family income are below that in population median.
#   * They consider themselves are in working class or lower class. They think their family income is below average.
#   * They and their family don't have higher education. About high school degree.
#   * Their husbands work 40-50 hrs per week.
#   * More of them living in apartment houses.
#   * They are not religous
#
#   ### summary: sort of in between cluster 1 and 2. They don't work possibly because spouse works full time.

# %% [markdown]
# ## 4. Employed Class

# %% [markdown]
# ### Cluster 0

# %%
one_res_all(df,0)

# %%
c0 = fc_df[fc_df.cluster ==0]

sort_feature_means(c0,10)
# Out:
# [(0.042080973391574079, 'coninc'),
#  (0.021046270006271194, 'degree'),
#  (0.01324399045827203, 'age'),
#  (0.010083204302881267, 'educom'),
#  (0.0092835604906183634, 'agekdbrn'),
#  (0.0076032508735443816, 'sphrs1'),
#  (0.0065322028558504911, 'class_'),
#  (0.0065133198555721722, 'polviews'),
#  (0.0061523862357446696, 'partyid'),
#  (0.0056848289513118048, 'finrela')]

# %% [markdown]
# ### Degree

# %%
cluster_ztest_df(one_res_bar(df,0,'degree'))
# Out:
# [(u'Bachelor', 9.73, 0.0),
#  (u'Graduate', 7.8, 0.0),
#  (u'High school', 3.22, 0.0),
#  (u'Junior college', 6.29, 0.0)]

# %% [markdown]
# ## class

# %%
cluster_ztest_df(one_res_bar(df,0,'class_'))
# Out:
# [(u'Middle class', 6.78, 0.0),
#  (u'Lower class', -12.7, 0.0),
#  (u'Upper class', -2.94, 0.0)]

# %% [markdown]
# ### Politcal Views

# %%
cluster_ztest_df(one_res_bar(df,0,'polviews'),False)
# Out:
# [(u"Don't know", -7.44, 0.0),
#  (u'Extrmly conservative', -4.79, 0.0),
#  (u'Liberal', 2.76, 0.0),
#  (u'Slghtly conservative', 2.57, 0.01)]

# %% [markdown]
# ## partyid

# %%
cluster_ztest_df(one_res_bar(df,0,'partyid'),False)
# Out:
# [(u'Independent', -8.28, 0.0),
#  (u'Not str republican', 4.21, 0.0),
#  (u'Strong democrat', 2.36, 0.01),
#  (u'Not str democrat', 2.06, 0.02)]

# %% [markdown]
# ## Financial situation

# %%
cluster_ztest_df(one_res_bar(df,0,'finrela'))
# Out:
# [(u'Above average', 7.14, 0.0),
#  (u'Average', 9.95, 0.0),
#  (u'Below average', -8.6, 0.0),
#  (u'Far below average', -11.86, 0.0)]

# %%
cluster_ztest_df(one_res_bar(df,0,'dwelling'))
# Out:
# [(u'3-4 fam house', -3.41, 0.0),
#  (u'Apartment house', -5.42, 0.0),
#  (u'Detached 1-fam house', 10.06, 0.0)]

# %% [markdown]
# ## Women in cluster 0 have the following characteratics:
#
#   * Family incomes are about upper stream of the public
#   * They have high degrees (at least high school) **main driver**
#   * They gave birth to their first kids later.
#   * Husbands also work full time, 42 hrs/wk
#   * They consider themselves working or middle class.
#   * Lesser of them answer partyid or politival views with "Don't know" or "independent", so they probably have strong opinions.
#
#   ## summary: having higher education degree, having kids late

# %% [markdown]
# ## Cluster 3

# %%
one_res_all(df,3)

# %%
one_pub_hist_mat(df,3,'sphrs1',True)

# %%
c3 = fc_df[fc_df.cluster ==3]

sort_feature_means(c3,10)
# Out:
# [(-0.047762039104025079, 'coninc'),
#  (0.030098106242422738, 'degree'),
#  (0.013892893577860029, 'age'),
#  (0.011935504426411342, 'educom'),
#  (0.0093276884605862746, 'agekdbrn'),
#  (0.0085354185432496652, 'partyid'),
#  (0.0084588006421188345, 'class_'),
#  (0.0077407653275778183, 'marital'),
#  (0.0075419990811757525, 'dwelling'),
#  (0.0072906876098014989, 'divorce')]

# %% [markdown]
# ### Degree

# %%
cluster_ztest_df(one_res_bar(df,3,'degree'))
# Out:
# [(u'Bachelor', -4.62, 0.0), (u'High school', 11.31, 0.0)]

# %% [markdown]
# ## partyid

# %%
cluster_ztest_df(one_res_bar(df,3,'partyid'))
# Out:
# [(u'Ind,near rep', -3.05, 0.0), (u'Independent', 3.71, 0.0)]

# %% [markdown]
# ## class

# %%
cluster_ztest_df(one_res_bar(df,3,'class_'))
# Out:
# [(u'Working class', 5.59, 0.0), (u'Middle class', -5.4, 0.0)]

# %% [markdown]
# ## Marital

# %%
one_pub_bar(df,3,'marital')

# %% [markdown]
# ## Dwelling

# %%
cluster_ztest_df(one_res_bar(df,3,'dwelling'))
# Out:
# [(u'Apartment house', 5.65, 0.0), (u'Detached 1-fam house', -6.54, 0.0)]

# %%
cluster_ztest_df(one_res_bar(df,3,'finrela'))
# Out:
# [(u'Above average', -3.98, 0.0),
#  (u'Average', -3.94, 0.0),
#  (u'Below average', 5.65, 0.0),
#  (u'Far below average', 3.04, 0.0),
#  (u'No answer', 4.69, 0.0)]

# %% [markdown]
# ### Women in cluster 3 have following characteristics:
#   * Family income are below population. They consider their finicial situation below average.
#   * Majority of them have high school degree.
#   * more of them consider themselves working class
#   * Most of them are Never married or divorced. ** they are single moms. Main difference**
#
#
#  ## summary: well educated, single moms. working class

# %% [markdown]
# ## Cluster 4

# %%
one_res_all(df,4)

# %%
c4 = fc_df[fc_df.cluster ==4]

sort_feature_means(c4,10)
# Out:
# [(-0.112494637432098, 'degree'),
#  (0.023824348249125188, 'coninc'),
#  (0.019713158066941121, 'age'),
#  (0.012102558777930487, 'educom'),
#  (0.011566590279362654, 'dwelling'),
#  (0.011441392099877318, 'agekdbrn'),
#  (0.010129008147363151, 'incom16'),
#  (0.010116250691920407, 'polviews'),
#  (0.010062968834124908, 'partyid'),
#  (0.0095081045009339886, 'res16')]

# %% [markdown]
# ## degree

# %%
cluster_ztest_df(one_res_bar(df,4,'degree'))
# Out:
# [(u'Lt high school', 41.08, 0.0)]

# %% [markdown]
# ## dwelling

# %%
cluster_ztest_df(one_res_bar(df,4,'dwelling'))
# Out:
# [(u'Detached 1-fam house', -4.59, 0.0)]

# %% [markdown]
# ## income 16

# %%
cluster_ztest_df(one_res_bar(df,4,'incom16'))
# Out:
# [(u'Above average', -3.43, 0.0), (u'Far below average', 4.38, 0.0)]

# %% [markdown]
# ### Political Views

# %%
cluster_ztest_df(one_res_bar(df,4,'polviews'))
# Out:
# [(u"Don't know", 5.9, 0.0)]

# %% [markdown]
# ## party id

# %%
cluster_ztest_df(one_res_bar(df,4,'partyid'))
# Out:
# [(u'Independent', 5.62, 0.0)]

# %% [markdown]
# ## res 16

# %%
cluster_ztest_df(one_res_bar(df,4,'res16'))
# Out:
# [(u'Big-city suburb', -2.94, 0.0)]

# %% [markdown]
# ## Religion

# %%
cluster_ztest_df(one_res_bar(df,4,'reliten'))
# Out:
# [(u'Strong', -3.32, 0.0), (u'No religion', 3.42, 0.0)]

# %% [markdown]
# ## Women in cluster 4 have following characterastics:
#   * Have first kid early, their ideal number of children is lower than public.
#   * Family has less eudcation than generage population
#   * Don't have strong affiliation to religions
#   * Moderate or have no interest in political views.
#   * Less than high school degree
#   * Low family income and consider their family income is below avereage
#
#   ## Summary: Women in this cluster share lots in common with women in cluster 1, but they work. And maybe for the sake of they work, they sometimes spend evenings with friends.

# %% [markdown]
# ## To do:
#
# ###  compare 1 and 4
